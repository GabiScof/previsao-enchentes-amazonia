# %% [markdown]
# # GridSearch Manual

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score

from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import itertools

# === 1. Carregar dados ===
df = pd.read_csv('/content/drive/MyDrive/Projeto Ciência de Dados/dados-manaus-preprocessado.csv')
df = df[df['ano'] >= 2000].drop(columns=['municipio', 'uf'])
X_df = df.drop(columns='vazao')
y_df = df['vazao']
target_column = 'vazao'
target_index = df.columns.get_loc(target_column)

# === 2. Normalizar ===
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# === 3. Função para criar janelas ===
def create_multistep_sequences(data, target_index, window_size, forecast_horizon):
    X, y = [], []
    for i in range(len(data) - window_size - forecast_horizon):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size:i+window_size+forecast_horizon, target_index])
    return np.array(X), np.array(y)

# === 4. Função para treinar modelo ===
def run_experiment(window_size, epochs, batch_size, val_split, verbose):
    forecast_horizon = window_size // 2
    X, y = create_multistep_sequences(scaled_data, target_index, window_size, forecast_horizon)
    split = int(0.8 * len(X))
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    model = Sequential()
    model.add(Input(shape=(X.shape[1], X.shape[2])))
    model.add(LSTM(64))
    model.add(Dropout(0.3))
    model.add(Dense(forecast_horizon))
    model.compile(optimizer='adam', loss='mse')

    es = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
    history = model.fit(X_train, y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_split=val_split,
                        callbacks=[es],
                        verbose=verbose)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Reverter normalização
    scale = scaler.scale_[target_index]
    min_ = scaler.min_[target_index]
    def denorm(y): return y * (1 / scale) + min_

    y_train_real = denorm(y_train)
    y_test_real = denorm(y_test)
    y_train_pred_real = denorm(y_train_pred)
    y_test_pred_real = denorm(y_test_pred)

    # Métricas (média dos horizontes)
    rmse_train = np.mean([np.sqrt(mean_squared_error(y_train_real[:, i], y_train_pred_real[:, i])) for i in range(forecast_horizon)])
    rmse_test = np.mean([np.sqrt(mean_squared_error(y_test_real[:, i], y_test_pred_real[:, i])) for i in range(forecast_horizon)])
    r2_train = np.mean([r2_score(y_train_real[:, i], y_train_pred_real[:, i]) for i in range(forecast_horizon)])
    r2_test = np.mean([r2_score(y_test_real[:, i], y_test_pred_real[:, i]) for i in range(forecast_horizon)])

    return {
        'window_size': window_size,
        'forecast_horizon': forecast_horizon,
        'epochs': epochs,
        'batch_size': batch_size,
        'val_split': val_split,
        'verbose': verbose,
        'rmse_train': rmse_train,
        'rmse_test': rmse_test,
        'r2_train': r2_train,
        'r2_test': r2_test
    }

# === 5. Hiperparâmetros a testar ===
param_grid = {
    'window_size': [14, 30, 50],
    'epochs': [50, 100],
    'batch_size': [16, 32],
    'val_split': [0.1, 0.2],
    'verbose': [0]  # Mantenha 0 para não lotar o output
}

combinations = list(itertools.product(*param_grid.values()))

# === 6. Rodar experimentos ===
results = []
for params in combinations:
    config = dict(zip(param_grid.keys(), params))
    print(f"Executando: {config}")
    result = run_experiment(**config)
    print(result)
    results.append(result)

# === 7. Salvar resultados ===
results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by='r2_test', ascending=False)
results_df.to_csv('/content/resultados_LSTM_param_grid.csv', index=False)

# Mostrar top 5 resultados
print("\nTop 5 combinações:")
print(results_df.head())
# Out:
# Executando: {'window_size': 14, 'epochs': 50, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'window_size': 14, 'forecast_horizon': 7, 'epochs': 50, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(2912.26359843662), 'rmse_test': np.float64(6395.745292979421), 'r2_train': np.float64(0.9944749540117209), 'r2_test': np.float64(0.9767320042946827)}
# Executando: {'window_size': 14, 'epochs': 50, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'window_size': 14, 'forecast_horizon': 7, 'epochs': 50, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(2925.3965457753657), 'rmse_test': np.float64(6247.339908526874), 'r2_train': np.float64(0.9945253120720032), 'r2_test': np.float64(0.9776824853206121)}
# Executando: {'window_size': 14, 'epochs': 50, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# {'window_size': 14, 'forecast_horizon': 7, 'epochs': 50, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(2971.940149584144), 'rmse_test': np.float64(6474.089692329076), 'r2_train': np.float64(0.9943556052284698), 'r2_test': np.float64(0.9761728853304684)}
# Executando: {'window_size': 14, 'epochs': 50, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'window_size': 14, 'forecast_horizon': 7, 'epochs': 50, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(2541.3520764875984), 'rmse_test': np.float64(7207.7723998099855), 'r2_train': np.float64(0.9957937072344692), 'r2_test': np.float64(0.9703071869792748)}
# Executando: {'window_size': 14, 'epochs': 100, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'window_size': 14, 'forecast_horizon': 7, 'epochs': 100, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(2549.1408183634912), 'rmse_test': np.float64(6118.045380143854), 'r2_train': np.float64(0.9957850721520829), 'r2_test': np.float64(0.9785612986445825)}
# Executando: {'window_size': 14, 'epochs': 100, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# {'window_size': 14, 'forecast_horizon': 7, 'epochs': 100, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(2340.667596680498), 'rmse_test': np.float64(6215.443750226272), 'r2_train': np.float64(0.996387017194964), 'r2_test': np.float64(0.9776235610198444)}
# Executando: {'window_size': 14, 'epochs': 100, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'window_size': 14, 'forecast_horizon': 7, 'epochs': 100, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(2925.6315322462483), 'rmse_test': np.float64(6609.700858862993), 'r2_train': np.float64(0.9945840854243134), 'r2_test': np.float64(0.9752711878978485)}
# Executando: {'window_size': 14, 'epochs': 100, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# {'window_size': 14, 'forecast_horizon': 7, 'epochs': 100, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(2496.934596302948), 'rmse_test': np.float64(6535.412833951307), 'r2_train': np.float64(0.9959426520634285), 'r2_test': np.float64(0.9755859339277813)}
# Executando: {'window_size': 30, 'epochs': 50, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# {'window_size': 30, 'forecast_horizon': 15, 'epochs': 50, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(3437.939021877147), 'rmse_test': np.float64(8691.144929124444), 'r2_train': np.float64(0.9920492504594863), 'r2_test': np.float64(0.9543847003273219)}
# Executando: {'window_size': 30, 'epochs': 50, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# {'window_size': 30, 'forecast_horizon': 15, 'epochs': 50, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(3618.31656009579), 'rmse_test': np.float64(8693.146598158499), 'r2_train': np.float64(0.99120447947627), 'r2_test': np.float64(0.9542593686663661)}
# Executando: {'window_size': 30, 'epochs': 50, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# {'window_size': 30, 'forecast_horizon': 15, 'epochs': 50, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(4536.098026207527), 'rmse_test': np.float64(8542.557653888496), 'r2_train': np.float64(0.9870955898773082), 'r2_test': np.float64(0.9566511219722325)}
# Executando: {'window_size': 30, 'epochs': 50, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# {'window_size': 30, 'forecast_horizon': 15, 'epochs': 50, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(3978.8495173734104), 'rmse_test': np.float64(9910.14308238922), 'r2_train': np.float64(0.9893135374776155), 'r2_test': np.float64(0.9423457136648336)}
# Executando: {'window_size': 30, 'epochs': 100, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'window_size': 30, 'forecast_horizon': 15, 'epochs': 100, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(3936.985578865533), 'rmse_test': np.float64(8019.430070800717), 'r2_train': np.float64(0.9896875451907146), 'r2_test': np.float64(0.9620063301691271)}
# Executando: {'window_size': 30, 'epochs': 100, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'window_size': 30, 'forecast_horizon': 15, 'epochs': 100, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(4749.310956084311), 'rmse_test': np.float64(9673.970919601214), 'r2_train': np.float64(0.9858281961366477), 'r2_test': np.float64(0.9435986154049839)}
# Executando: {'window_size': 30, 'epochs': 100, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# {'window_size': 30, 'forecast_horizon': 15, 'epochs': 100, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(3863.4493028314205), 'rmse_test': np.float64(9055.752691988362), 'r2_train': np.float64(0.9900536646572461), 'r2_test': np.float64(0.9518747519558477)}
# Executando: {'window_size': 30, 'epochs': 100, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0}
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'window_size': 30, 'forecast_horizon': 15, 'epochs': 100, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(3904.5025215936403), 'rmse_test': np.float64(9666.97675197805), 'r2_train': np.float64(0.9898235006142296), 'r2_test': np.float64(0.9436519796667313)}
# Executando: {'window_size': 50, 'epochs': 50, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0}
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# {'window_size': 50, 'forecast_horizon': 25, 'epochs': 50, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(5258.426433894498), 'rmse_test': np.float64(13163.887929936807), 'r2_train': np.float64(0.9809450084668013), 'r2_test': np.float64(0.8948078633050897)}
# Executando: {'window_size': 50, 'epochs': 50, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0}
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# {'window_size': 50, 'forecast_horizon': 25, 'epochs': 50, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(5123.355761732598), 'rmse_test': np.float64(13059.337499353944), 'r2_train': np.float64(0.9822262542984795), 'r2_test': np.float64(0.8957962189931865)}
# Executando: {'window_size': 50, 'epochs': 50, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0}
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'window_size': 50, 'forecast_horizon': 25, 'epochs': 50, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(6970.113795403494), 'rmse_test': np.float64(12698.66304272527), 'r2_train': np.float64(0.9670930286600746), 'r2_test': np.float64(0.903588085033107)}
# Executando: {'window_size': 50, 'epochs': 50, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0}
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# {'window_size': 50, 'forecast_horizon': 25, 'epochs': 50, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(6723.83586193881), 'rmse_test': np.float64(12278.317577999807), 'r2_train': np.float64(0.9705045497181675), 'r2_test': np.float64(0.9107291801811465)}
# Executando: {'window_size': 50, 'epochs': 100, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0}
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# {'window_size': 50, 'forecast_horizon': 25, 'epochs': 100, 'batch_size': 16, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(6015.250798212347), 'rmse_test': np.float64(14551.498672510696), 'r2_train': np.float64(0.9750136438608402), 'r2_test': np.float64(0.8679824435763357)}
# Executando: {'window_size': 50, 'epochs': 100, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0}
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# {'window_size': 50, 'forecast_horizon': 25, 'epochs': 100, 'batch_size': 16, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(5884.159943258499), 'rmse_test': np.float64(13104.719135394738), 'r2_train': np.float64(0.9767547860103665), 'r2_test': np.float64(0.8931189992268418)}
# Executando: {'window_size': 50, 'epochs': 100, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0}
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# {'window_size': 50, 'forecast_horizon': 25, 'epochs': 100, 'batch_size': 32, 'val_split': 0.1, 'verbose': 0, 'rmse_train': np.float64(4991.682175176872), 'rmse_test': np.float64(12030.378501317271), 'r2_train': np.float64(0.9833027857481476), 'r2_test': np.float64(0.9127675682673714)}
# Executando: {'window_size': 50, 'epochs': 100, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0}
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# {'window_size': 50, 'forecast_horizon': 25, 'epochs': 100, 'batch_size': 32, 'val_split': 0.2, 'verbose': 0, 'rmse_train': np.float64(6948.256171312336), 'rmse_test': np.float64(12449.421939818065), 'r2_train': np.float64(0.969766375218069), 'r2_test': np.float64(0.9048528815752923)}
#
# Top 5 combinações:
#    window_size  forecast_horizon  epochs  batch_size  val_split  verbose  \
# 4           14                 7     100          16        0.1        0
# 1           14                 7      50          16        0.2        0
# 5           14                 7     100          16        0.2        0
# 0           14                 7      50          16        0.1        0
# 2           14                 7      50          32        0.1        0
#
#     rmse_train    rmse_test  r2_train   r2_test
# 4  2549.140818  6118.045380  0.995785  0.978561
# 1  2925.396546  6247.339909  0.994525  0.977682
# 5  2340.667597  6215.443750  0.996387  0.977624
# 0  2912.263598  6395.745293  0.994475  0.976732
# 2  2971.940150  6474.089692  0.994356  0.976173
